# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.utils import pad_sequences
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras import Model, Input
from keras.layers import LSTM, Embedding, Dense
from keras.layers import TimeDistributed, SpatialDropout1D, Bidirectional
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv("/content/ner_dataset.csv", encoding="latin1")
data=data.fillna(method="ffill")
data.head(20)
# Out:
#      Sentence #           Word  POS    Tag
# 0   Sentence: 1      Thousands  NNS      O
# 1   Sentence: 1             of   IN      O
# 2   Sentence: 1  demonstrators  NNS      O
# 3   Sentence: 1           have  VBP      O
# 4   Sentence: 1        marched  VBN      O
# 5   Sentence: 1        through   IN      O
# 6   Sentence: 1         London  NNP  B-geo
# 7   Sentence: 1             to   TO      O
# 8   Sentence: 1        protest   VB      O
# 9   Sentence: 1            the   DT      O
# 10  Sentence: 1            war   NN      O
# 11  Sentence: 1             in   IN      O
# 12  Sentence: 1           Iraq  NNP  B-geo
# 13  Sentence: 1            and   CC      O
# 14  Sentence: 1         demand   VB      O
# 15  Sentence: 1            the   DT      O
# 16  Sentence: 1     withdrawal   NN      O
# 17  Sentence: 1             of   IN      O
# 18  Sentence: 1        British   JJ  B-gpe
# 19  Sentence: 1         troops  NNS      O

# %%
print("Unique words in corpus:",data['Word'].nunique())
print("Unique tags in corpus:",data['Tag'].nunique())
# Out:
# Unique words in corpus: 23008
# Unique tags in corpus: 17

# %%
words=list(set(data["Word"].values))
words.append("ENDPAD")
num_words=len(words)

# %%
tags=list(set(data["Tag"].values))
num_tags=len(tags)

# %%
class SentenceGetter(object):
    def __init__(self, data):
        self.n_sent=1
        self.data=data
        self.empty=False
        agg_func=lambda s:[(w, p, t) for w, p, t in zip(s["Word"].values.tolist(),
                                                           s["POS"].values.tolist(),
                                                           s["Tag"].values.tolist())]
        self.grouped=self.data.groupby("Sentence #").apply(agg_func)
        self.sentences=[s for s in self.grouped]
    
    def get_next(self):
        try:
            s=self.grouped["Sentence: {}".format(self.n_sent)]
            self.n_sent+=1
            return s
        except:
            return None

# %%
getter=SentenceGetter(data)
sentences=getter.sentences

# %%
sentences[0]
# Out:
# [('Thousands', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('demonstrators', 'NNS', 'O'),
#  ('have', 'VBP', 'O'),
#  ('marched', 'VBN', 'O'),
#  ('through', 'IN', 'O'),
#  ('London', 'NNP', 'B-geo'),
#  ('to', 'TO', 'O'),
#  ('protest', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('war', 'NN', 'O'),
#  ('in', 'IN', 'O'),
#  ('Iraq', 'NNP', 'B-geo'),
#  ('and', 'CC', 'O'),
#  ('demand', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('withdrawal', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('British', 'JJ', 'B-gpe'),
#  ('troops', 'NNS', 'O'),
#  ('from', 'IN', 'O'),
#  ('that', 'DT', 'O'),
#  ('country', 'NN', 'O'),
#  ('.', '.', 'O')]

# %%
word2idx={w:i + 1 for i, w in enumerate(words)}
tag2idx={t:i for i, t in enumerate(tags)}

# %%
word2idx
# Out:
# {'twice': 1,
#  'reflects': 2,
#  'beheaded': 3,
#  'open-ended': 4,
#  'professionalism': 5,
#  'SCHROEDER': 6,
#  'calmer': 7,
#  'Hugh': 8,
#  'Jean-Cyril': 9,
#  'generals': 10,
#  '28': 11,
#  'claim': 12,
#  'George': 13,
#  'Vines': 14,
#  'cancel': 15,
#  'guaranteeing': 16,
#  'Pekanbara': 17,
#  'Completing': 18,
#  'ingredients': 19,
#  'Kajaki': 20,
#  'hunts': 21,
#  'expansion': 22,
#  'Hong-Kong-based': 23,
#  'contractual': 24,
#  'tunnel': 25,
#  '15': 26,
#  'spot': 27,
#  'Bode': 28,
#  'Lefevre': 29,
#  'Holocaust': 30,
#  're-stating': 31,
#  'errant': 32,
#  '240': 33,
#  'Fleihan': 34,
#  'Out': 35,
#  'positive': 36,
#  'entirely': 37,
#  'overhead': 38,
#  'Pingtung': 39,
#  'exceptional': 40,
#  'pushed': 41,
#  'upgrading': 42,
#  'Redmond': 43,
#  '1621': 44,
#  'zoo': 45,
#  '994': 46,
#  'bet': 47,
#  'Griffal': 48,
#  '%': 49,
#  'Likewise': 50,
#  'dialog': 51,
#  'reformists': 52,
#  'hopefuls': 53,
#  'Technology': 54,
#  'editorials': 55,
#  'Kissem': 56,
#  'match-up': 57,
#  'stockpiled': 58,
#  'rifles': 59,
#  'Rotterdam': 60,
#  'shall': 61,
#  'opposition': 62,
#  'Sharm-el-Sheik': 63,
#  'pipeline': 64,
#  'Patriots': 65,
#  'Azerbaijan': 66,
#  'intimidated': 67,
#  'charcoal': 68,
#  'slide': 69,
#  'popular': 70,
#  'second-ranking': 71,
#  'doors': 72,
#  'clergy': 73,
#  'withdrawals': 74,
#  'Tripura': 75,
#  'currencies': 76,
#  'Chicken': 77,
#  'Macy': 78,
#  'incredibly': 79,
#  'streamlined': 80,
#  'senseless': 81,
#  'Why': 82,
#  '1993': 83,
#  'rescued': 84,
#  'hosting': 85,
#  'Considered': 86,
#  'recognition': 87,
#  'chosen': 88,
#  'anti-labor': 89,
#  'Mitterndorf': 90,
#  'Joint': 91,
#  'Abdullah': 92,
#  'Soviet-dominated': 93,
#  'hanged': 94,
#  'cholera': 95,
#  'extinct': 96,
#  'abandon': 97,
#  'Democratia': 98,
#  'RIA-Novosti': 99,
#  'Tayyeb': 100,
#  'Rangin': 101,
#  'protester': 102,
#  'Herzegovina': 103,
#  'mathematician': 104,
#  'undergone': 105,
#  'Mbabane': 106,
#  'Dongfeng': 107,
#  'ring': 108,
#  'retail': 109,
#  'pro-business': 110,
#  'rent': 111,
#  'curriculum': 112,
#  'salinity': 113,
#  'Champions': 114,
#  'enduring': 115,
#  'unions': 116,
#  'Unfortunately': 117,
#  'Ljubicic': 118,
#  'Tobago': 119,
#  'Eugenio': 120,
#  'pro-Thaksin': 121,
#  'Amorim': 122,
#  'naming': 123,
#  'stores': 124,
#  'Aswat': 125,
#  'Damn': 126,
#  'Duluth': 127,
#  'performance-enhancing': 128,
#  'spokesman': 129,
#  'winners': 130,
#  'yearly': 131,
#  'rebel-held': 132,
#  'cheeks': 133,
#  'installs': 134,
#  'Director': 135,
#  'Kashmir': 136,
#  'openly': 137,
#  'tramway': 138,
#  'insurgency-related': 139,
#  'unused': 140,
#  'Badghis': 141,
#  'e.g.': 142,
#  'Gerard': 143,
#  'Ruthenians': 144,
#  'irregularities': 145,
#  'collaborated': 146,
#  'Karabilah': 147,
#  '1776': 148,
#  'wool': 149,
#  'bypass': 150,
#  'fever': 151,
#  'Elaine': 152,
#  'sealing': 153,
#  'nightclub': 154,
#  'Hector': 155,
#  'raids': 156,
#  'coordination': 157,
#  'demolishing': 158,
#  'product': 159,
#  'holding': 160,
#  'vain': 161,
#  'theory': 162,
#  'Rehman': 163,
#  'infrastructure': 164,
#  'Scattered': 165,
#  'surface-to-surface': 166,
#  'Brownback': 167,
#  'technician': 168,
#  '733': 169,
#  'veteran': 170,
#  'last': 171,
#  'mail': 172,
#  'Pirates': 173,
#  'settle': 174,
#  'Aalam': 175,
#  'concerts': 176,
#  'chips': 177,
#  'grabs': 178,
#  'paints': 179,
#  'motorists': 180,
#  'Agreements': 181,
#  'Vancouver': 182,
#  'Torbat-e-Heydariyeh': 183,
#  'Ho': 184,
#  'plunder': 185,
#  'carries': 186,
#  'working': 187,
#  'endorsement': 188,
#  'convey': 189,
#  'BULL': 190,
#  'Ghassan': 191,
#  'styled': 192,
#  'tracks': 193,
#  'Rezai': 194,
#  'consistent': 195,
#  'shut': 196,
#  'failures': 197,
#  'dating': 198,
#  'sabotaged': 199,
#  'views': 200,
#  'visiting': 201,
#  'volatile': 202,
#  'freighter': 203,
#  'solar-electric': 204,
#  'Security': 205,
#  'MILLS': 206,
#  'H5': 207,
#  'Kajo': 208,
#  'ex-Clinton': 209,
#  'Guadalupe': 210,
#  'retake': 211,
#  'fuels': 212,
#  'Gana': 213,
#  'quartet': 214,
#  'cans': 215,
#  'Administrator': 216,
#  'Sharia': 217,
#  'taxis': 218,
#  'Local': 219,
#  'copies': 220,
#  'anemic': 221,
#  'enforcing': 222,
#  'Heathens': 223,
#  'One': 224,
#  'Veritas': 225,
#  'Usmani': 226,
#  'housing': 227,
#  'cigarettes': 228,
#  'resisted': 229,
#  'Hakim': 230,
#  'affected': 231,
#  'FOWLER': 232,
#  'glitch': 233,
#  'settlement': 234,
#  'tangible': 235,
#  'Swede': 236,
#  'bear': 237,
#  'Berger': 238,
#  'block-by-block': 239,
#  'lonely': 240,
#  'command': 241,
#  'combatants': 242,
#  'Protection': 243,
#  'watch': 244,
#  '223': 245,
#  'anti-government': 246,
#  'underway': 247,
#  'Salazar': 248,
#  'matches': 249,
#  'Chemical': 250,
#  'dedicate': 251,
#  'permitting': 252,
#  'Nursultan': 253,
#  'Canberra': 254,
#  'Cuba': 255,
#  'programming': 256,
#  'deals': 257,
#  'station': 258,
#  'considerably': 259,
#  'Budget': 260,
#  'macro-economic': 261,
#  'manuscript': 262,
#  'religion-based': 263,
#  'setbacks': 264,
#  'quoting': 265,
#  'inexpensive': 266,
#  'primitive': 267,
#  'extracted': 268,
#  'Aref': 269,
#  'ambitious': 270,
#  'Danube': 271,
#  'Netanyahu': 272,
#  'Sanctuary': 273,
#  'operator': 274,
#  'Rhine-Westphalia': 275,
#  'Hashemi': 276,
#  'Cathedral': 277,
#  'exporting': 278,
#  'parades': 279,
#  'contains': 280,
#  'folks': 281,
#  'Cowell': 282,
#  'Denis': 283,
#  'overnight': 284,
#  'Soviet-made': 285,
#  'discount': 286,
#  'USSR': 287,
#  'Nasr': 288,
#  'gullet-bag': 289,
#  'induced': 290,
#  'symptoms': 291,
#  'expresses': 292,
#  'countryman': 293,
#  'kilometer': 294,
#  'AP': 295,
#  'date': 296,
#  'bloated': 297,
#  'multimillion': 298,
#  'excellent': 299,
#  'endorses': 300,
#  'shifted': 301,
#  'kingdom': 302,
#  '673': 303,
#  'Panjwayi': 304,
#  'borrow': 305,
#  '20-year': 306,
#  'Baghdad': 307,
#  'musical': 308,
#  'Fisher-Price': 309,
#  'create': 310,
#  'Adana': 311,
#  'Somalis': 312,
#  'Band': 313,
#  'Carly': 314,
#  'vacationing': 315,
#  'exiled': 316,
#  'late': 317,
#  'index': 318,
#  '30s': 319,
#  'Qamdo': 320,
#  'silos': 321,
#  'Dyrdina': 322,
#  'Opponents': 323,
#  'Baez': 324,
#  'stressed': 325,
#  'al-Maliki': 326,
#  'signaled': 327,
#  'fresco': 328,
#  'coordinated': 329,
#  'Mexico': 330,
#  'Iraqi': 331,
#  'Chairman': 332,
#  'C': 333,
#  'defendants': 334,
#  'emigrants': 335,
#  'fundamental': 336,
#  'alleviating': 337,
#  'strategies': 338,
#  'Prizes': 339,
#  'Mahalia': 340,
#  'Obita': 341,
#  'starvation': 342,
#  'strength': 343,
#  'outlook': 344,
#  '113.2': 345,
#  'plunge': 346,
#  'require': 347,
#  'beatings': 348,
#  'Ellen': 349,
#  'Zahedan': 350,
#  'contributes': 351,
#  'Also': 352,
#  'career-best': 353,
#  'Exchange': 354,
#  'sweltering': 355,
#  'chanting': 356,
#  'Measured': 357,
#  'radical': 358,
#  'Chiapas': 359,
#  'independently': 360,
#  'Attention': 361,
#  'outdo': 362,
#  'yesterday': 363,
#  'mine': 364,
#  'six-year-old': 365,
#  'Gustav': 366,
#  'reacting': 367,
#  'lend': 368,
#  'attach': 369,
#  'Claudia': 370,
#  'roof': 371,
#  'Kristin': 372,
#  'Salim': 373,
#  'public-private': 374,
#  'Operations': 375,
#  '185': 376,
#  'trains': 377,
#  'Bonaire': 378,
#  'mutiny': 379,
#  'away': 380,
#  'harms': 381,
#  'Noble': 382,
#  'Airline': 383,
#  'conservationists': 384,
#  'W.': 385,
#  'ace': 386,
#  'Seppi': 387,
#  'butchers': 388,
#  'bio-terrorism': 389,
#  'ample': 390,
#  'synchronize': 391,
#  'Zulima': 392,
#  'devil': 393,
#  'after-tax': 394,
#  '1952': 395,
#  'puts': 396,
#  'connecting': 397,
#  'Zamir': 398,
#  'systemic': 399,
#  'Wipha': 400,
#  'Mattoo': 401,
#  'rig': 402,
#  'Employment': 403,
#  'showed': 404,
#  'nationalizing': 405,
#  'dire': 406,
#  'observation': 407,
#  'Loney': 408,
#  'Bolshevik': 409,
#  'taunting': 410,
#  'beyond': 411,
#  'Catalonia': 412,
#  'spokeswoman': 413,
#  '1948': 414,
#  'fisherman': 415,
#  'Deborah': 416,
#  'Diamondbacks': 417,
#  'Outgoing': 418,
#  'persist': 419,
#  'Mujaheddin': 420,
#  'yuan': 421,
#  'Ventures': 422,
#  'Tamiflu': 423,
#  'dark': 424,
#  'Ukraine': 425,
#  'altitudes': 426,
#  'Sinchulu': 427,
#  'headfirst': 428,
#  'Lieutenant': 429,
#  'Urdu': 430,
#  'sudden': 431,
#  'requirements': 432,
#  'gambling': 433,
#  'interwoven': 434,
#  'Trent': 435,
#  'replaced': 436,
#  'roots': 437,
#  'preventive': 438,
#  'Regions': 439,
#  'Marzieh': 440,
#  '07-Jun': 441,
#  'grasshoppers': 442,
#  'Guerrillas': 443,
#  '06-Apr': 444,
#  'Megawatt': 445,
#  'Denmark': 446,
#  'Teshiktosh': 447,
#  'PAN': 448,
#  'conventional': 449,
#  'gender': 450,
#  'slashing': 451,
#  'Sanders': 452,
#  'Vinci': 453,
#  'heightened': 454,
#  'tails': 455,
#  'Indian': 456,
#  'Beck': 457,
#  'Nation': 458,
#  'Gigi': 459,
#  'rampage': 460,
#  'Inacio': 461,
#  'frenzy': 462,
#  'Toshiyuki': 463,
#  'Marlon': 464,
#  'Various': 465,
#  'swapping': 466,
#  'rivalries': 467,
#  'dominant': 468,
#  'Abune': 469,
#  'poisoned': 470,
#  'farther': 471,
#  'jams': 472,
#  'regret': 473,
#  'homeowner': 474,
#  'averting': 475,
#  'categorically': 476,
#  '01-Jun': 477,
#  'Ninewa': 478,
#  'apologise': 479,
#  'turnover': 480,
#  'Nov.': 481,
#  'Mujuru': 482,
#  'restricted': 483,
#  'moratorium': 484,
#  'Citgo': 485,
#  'ski': 486,
#  'appointed': 487,
#  'aid': 488,
#  'Jordanian': 489,
#  'Signs': 490,
#  'photographed': 491,
#  'recover': 492,
#  'birthplace': 493,
#  'expelling': 494,
#  'necessitate': 495,
#  'Front': 496,
#  'Ayman': 497,
#  'Valle': 498,
#  'Shryock': 499,
#  'recorders': 500,
#  'Ministry': 501,
#  'ransom': 502,
#  'lateral': 503,
#  'on': 504,
#  'oxygen': 505,
#  'groundbreaking': 506,
#  'received': 507,
#  'sped': 508,
#  'Egebank': 509,
#  'reelected': 510,
#  'Late': 511,
#  'Undercover': 512,
#  'grills': 513,
#  'proof': 514,
#  'lawmaking': 515,
#  'Howard': 516,
#  'Gene': 517,
#  'Pakhtunkhwa': 518,
#  '1,09,000': 519,
#  'Bensouda': 520,
#  'pave': 521,
#  'Merka': 522,
#  'incumbents': 523,
#  'Industrial': 524,
#  'drought': 525,
#  'live-fire': 526,
#  'Brighton': 527,
#  'sadly': 528,
#  'install': 529,
#  'musician': 530,
#  'purposes': 531,
#  'Football': 532,
#  'Sarah': 533,
#  'enters': 534,
#  'required': 535,
#  'Councilor': 536,
#  'spaceship': 537,
#  'jewelry': 538,
#  'tributes': 539,
#  'field': 540,
#  '275': 541,
#  'Antarctica': 542,
#  'races': 543,
#  'P-50': 544,
#  'AIDS': 545,
#  'Anjar': 546,
#  'Thanh': 547,
#  'accords': 548,
#  'mini-stroke': 549,
#  'paddy': 550,
#  'avoided': 551,
#  'life-bearing': 552,
#  'lobster': 553,
#  '1,80,000': 554,
#  'skills': 555,
#  'everyone': 556,
#  'Yoshinori': 557,
#  'DAS': 558,
#  'crime': 559,
#  'participants': 560,
#  'foiled': 561,
#  'physical': 562,
#  'deeds': 563,
#  'Targets': 564,
#  'Donor': 565,
#  'comrades': 566,
#  'Zapatista': 567,
#  'charging': 568,
#  'co-educational': 569,
#  'donors': 570,
#  'fling': 571,
#  'censored': 572,
#  'survival': 573,
#  'lobbies': 574,
#  'attacked': 575,
#  'seen': 576,
#  'thanks': 577,
#  'India-Pakistan': 578,
#  'dangerous': 579,
#  'IAEA': 580,
#  'dwellings': 581,
#  'commemorations': 582,
#  'Elias': 583,
#  'anti-takeover': 584,
#  'Commonwealth': 585,
#  'Hayward': 586,
#  'cite': 587,
#  'economies': 588,
#  '182': 589,
#  'asserted': 590,
#  'specialists': 591,
#  'case': 592,
#  'three-fourths': 593,
#  'rowing': 594,
#  'Observatory': 595,
#  '722': 596,
#  'peaked': 597,
#  'Matt': 598,
#  '21,000': 599,
#  'Rana': 600,
#  'winters': 601,
#  'Datta': 602,
#  'Union': 603,
#  'squalid': 604,
#  'realized': 605,
#  'transplanting': 606,
#  'blank': 607,
#  'can': 608,
#  'lslamic': 609,
#  'Baran': 610,
#  'Steelers': 611,
#  'vibrant': 612,
#  'Schulte': 613,
#  'Photos': 614,
#  'debriefing': 615,
#  'Diabetes': 616,
#  'short-term': 617,
#  'Port-au-Prince': 618,
#  '94.2': 619,
#  'Ansar': 620,
#  'perceived': 621,
#  'banana': 622,
#  'overflowed': 623,
#  'Moghaddasi': 624,
#  'retain': 625,
#  'mutton': 626,
#  'Shell': 627,
#  'hijackers': 628,
#  'pictured': 629,
#  'idea': 630,
#  'designs': 631,
#  'south-west': 632,
#  'Ysidro': 633,
#  'Baathist': 634,
#  'merriment': 635,
#  '9.4': 636,
#  'Centers': 637,
#  'rioters': 638,
#  'COSATU': 639,
#  'famed': 640,
#  'Severe': 641,
#  '439': 642,
#  'stricken': 643,
#  'flame': 644,
#  'Investigative': 645,
#  'software': 646,
#  'walls': 647,
#  '787': 648,
#  'campaign': 649,
#  'ingredient': 650,
#  'assessing': 651,
#  'car-bomb': 652,
#  'Ahn': 653,
#  'responsive': 654,
#  'grains': 655,
#  'tape': 656,
#  'Jong': 657,
#  'succumbed': 658,
#  'Kiwis': 659,
#  '2023': 660,
#  'sprain': 661,
#  'Interviewed': 662,
#  'suffocating': 663,
#  'Algerians': 664,
#  'plenty': 665,
#  'opted': 666,
#  'practices': 667,
#  'Memorandum': 668,
#  'Ararat': 669,
#  'projection': 670,
#  'focus': 671,
#  'neighborhoods': 672,
#  'later': 673,
#  'Peasant': 674,
#  'Banks': 675,
#  'unseeded': 676,
#  'orbited': 677,
#  'colonel': 678,
#  'Mofaz': 679,
#  'hands': 680,
#  'biased': 681,
#  'five-month-long': 682,
#  'fall': 683,
#  'Police': 684,
#  'Hung': 685,
#  'raises': 686,
#  'Life': 687,
#  'Kenneth': 688,
#  'Etienne': 689,
#  'Bashar': 690,
#  'determined': 691,
#  'Reagan': 692,
#  'Filipino': 693,
#  'Pension': 694,
#  'Reformists': 695,
#  'gay': 696,
#  'Having': 697,
#  'colleague': 698,
#  'household': 699,
#  'drunk': 700,
#  'Palmer': 701,
#  'ISI': 702,
#  '21-year': 703,
#  'Anup': 704,
#  'confined': 705,
#  'recent': 706,
#  'Subsequent': 707,
#  '8.2': 708,
#  'pegged': 709,
#  'Restrictions': 710,
#  'Dragomir': 711,
#  'Yury': 712,
#  '85-year-old': 713,
#  'translator': 714,
#  'deliberations': 715,
#  'meters': 716,
#  'WHEN': 717,
#  'consular': 718,
#  'Adraskan': 719,
#  'Oakland': 720,
#  'DOG': 721,
#  'estimating': 722,
#  'Reasons': 723,
#  'retrieving': 724,
#  'Norwegians': 725,
#  'notes': 726,
#  'encompass': 727,
#  'Marcus': 728,
#  'foes': 729,
#  'track': 730,
#  'Samad': 731,
#  '7,00,000': 732,
#  'little': 733,
#  'skeletons': 734,
#  'processes': 735,
#  'Assistant': 736,
#  'Angelus': 737,
#  'Clay': 738,
#  '1962': 739,
#  '1963': 740,
#  'F-5': 741,
#  'clinics': 742,
#  'Chilean': 743,
#  'reassure': 744,
#  'two-thirds': 745,
#  'continue': 746,
#  'evicted': 747,
#  '19-day': 748,
#  'grievances': 749,
#  'Ruthenia': 750,
#  'Saud': 751,
#  'felony': 752,
#  'Fiction': 753,
#  'beside': 754,
#  'Rightwing': 755,
#  'Spring': 756,
#  'Omar': 757,
#  'ditch': 758,
#  'Plan': 759,
#  'reach': 760,
#  'touchstone': 761,
#  'Ethiopian-backed': 762,
#  'offers': 763,
#  'due': 764,
#  'Islamic': 765,
#  'diabetes': 766,
#  'Nations-backed': 767,
#  'Ouattara': 768,
#  'Bekaa': 769,
#  'unsettled': 770,
#  'airfare': 771,
#  'inside': 772,
#  'Sitaula': 773,
#  'CPJ': 774,
#  'mentally': 775,
#  'Foreign': 776,
#  'wine': 777,
#  'Rizgar': 778,
#  'MEND': 779,
#  'Buduburam': 780,
#  'tapped': 781,
#  'sitting': 782,
#  'translation': 783,
#  'NASA': 784,
#  'metro': 785,
#  'feature': 786,
#  'Shanghai-bound': 787,
#  'Primerica': 788,
#  'swine': 789,
#  'sources': 790,
#  'market-based': 791,
#  'ailment': 792,
#  'focusing': 793,
#  'Bigombe': 794,
#  'than': 795,
#  'Shana': 796,
#  'joined': 797,
#  'Muttawakil': 798,
#  'photograph': 799,
#  'demarcating': 800,
#  'harmed': 801,
#  'compiled': 802,
#  'Dean': 803,
#  'Bush': 804,
#  'standby-agreement': 805,
#  'Similar': 806,
#  'plotted': 807,
#  'Hubbard': 808,
#  'Mello': 809,
#  'motorway': 810,
#  'Militant': 811,
#  'learning': 812,
#  'CNN': 813,
#  'poison': 814,
#  'faxed': 815,
#  'torn': 816,
#  'seventh-century': 817,
#  'Israeli-imposed': 818,
#  'MIddle': 819,
#  'pro-Moscow': 820,
#  'honorary': 821,
#  'Shuttle': 822,
#  'peninsula': 823,
#  'LUKASHENKO': 824,
#  'Maori': 825,
#  'Jokic': 826,
#  'lion': 827,
#  'Agriculture': 828,
#  'Vilsack': 829,
#  'claims': 830,
#  'stranding': 831,
#  'cope': 832,
#  'Night': 833,
#  'bombers': 834,
#  '3': 835,
#  'plaintiff': 836,
#  '76.4': 837,
#  'classes': 838,
#  'nationally': 839,
#  'quake-damaged': 840,
#  'Perth': 841,
#  '108': 842,
#  'Busan': 843,
#  'Selim': 844,
#  'detonated': 845,
#  'Bu-young': 846,
#  'soccer': 847,
#  'Hilary': 848,
#  'Hokkaido': 849,
#  'Christiane': 850,
#  'venues': 851,
#  '7,50,000': 852,
#  'Merchants': 853,
#  'railroad': 854,
#  'altered': 855,
#  'Snagovo': 856,
#  'Ochami': 857,
#  'Peru': 858,
#  '2A': 859,
#  'trophy': 860,
#  'climatic': 861,
#  'abuse': 862,
#  'Nick': 863,
#  'Berlusconi': 864,
#  'euros': 865,
#  'strides': 866,
#  'mosquito-infested': 867,
#  'el-Sheikh': 868,
#  'Augusto': 869,
#  'fairer': 870,
#  'enriched': 871,
#  '11-year': 872,
#  'canceling': 873,
#  'Devra': 874,
#  '1,38,000': 875,
#  'supposed': 876,
#  '2900': 877,
#  'parlors': 878,
#  'amendment': 879,
#  'Abed': 880,
#  'Director-General': 881,
#  'waterways': 882,
#  '1949': 883,
#  'improves': 884,
#  'Wabara': 885,
#  'Fernando': 886,
#  'Bin': 887,
#  'street': 888,
#  'work': 889,
#  'Pedro': 890,
#  'Empire': 891,
#  'sergeant': 892,
#  'Schwab': 893,
#  'University': 894,
#  'piling': 895,
#  'OSCE': 896,
#  'Whittaker': 897,
#  'Amy': 898,
#  'Casey': 899,
#  'coping': 900,
#  'byes': 901,
#  'giants': 902,
#  'skirmish': 903,
#  'Boasting': 904,
#  'truce': 905,
#  'Pamela': 906,
#  '17-Jan': 907,
#  'auctioned': 908,
#  'instruments': 909,
#  'interference': 910,
#  'weaponry': 911,
#  'miners': 912,
#  'Teams': 913,
#  'withstand': 914,
#  'Dennis': 915,
#  'Hurtado': 916,
#  'verified': 917,
#  'Dhia': 918,
#  'buildup': 919,
#  'effects': 920,
#  'carry': 921,
#  'intermediate': 922,
#  'instability': 923,
#  'politics': 924,
#  'Thais': 925,
#  'Abdul-Aziz': 926,
#  'shantytown': 927,
#  'Fuheid': 928,
#  'cyclical': 929,
#  'Snake': 930,
#  'Acquisition': 931,
#  'Republican': 932,
#  'states': 933,
#  'Hossein': 934,
#  'shoplifting': 935,
#  'Elevators': 936,
#  '1997': 937,
#  'incompatible': 938,
#  'brought': 939,
#  'indicators': 940,
#  'Andorra': 941,
#  'comes': 942,
#  'supports': 943,
#  'expense': 944,
#  'Taepodong-2': 945,
#  'communist-era': 946,
#  'Beni': 947,
#  'priesthood': 948,
#  'caches': 949,
#  'Ticketing': 950,
#  'empowers': 951,
#  'ensuing': 952,
#  'Hamed': 953,
#  'Mae': 954,
#  'think': 955,
#  'lingering': 956,
#  'counting': 957,
#  'warmest': 958,
#  'Ereli': 959,
#  'barges': 960,
#  '1843': 961,
#  'Jakarta': 962,
#  'wooden': 963,
#  'malaria-fighting': 964,
#  'member-nations': 965,
#  'Joel': 966,
#  'Strait': 967,
#  'Customs': 968,
#  'bounty': 969,
#  'certified': 970,
#  'environment-friendly': 971,
#  'Looting': 972,
#  'Roads': 973,
#  'pledge': 974,
#  'Sahibzada': 975,
#  'complicate': 976,
#  'highest-rated': 977,
#  'Buttiglione': 978,
#  'Hence': 979,
#  'thwarted': 980,
#  'Dharmeratnam': 981,
#  '14-year': 982,
#  'pan-Iraqi': 983,
#  'Closing': 984,
#  'yellow-shirted': 985,
#  'parlimentary': 986,
#  'one-point-three': 987,
#  'Abdullahi': 988,
#  'Car': 989,
#  'al-Nejat': 990,
#  'belong': 991,
#  'Pin': 992,
#  'slaves': 993,
#  'Freedom': 994,
#  '450-seat': 995,
#  'Baiji': 996,
#  'audiences': 997,
#  'Champion': 998,
#  'stashes': 999,
#  'Carolina': 1000,
#  ...}

# %%
max_len=50
X=[[word2idx[w[0]] for w in s] for s in sentences]
X=pad_sequences(maxlen=max_len, sequences=X, padding="post", value=num_words-1)
y=[[tag2idx[w[2]] for w in s] for s in sentences]
y=pad_sequences(maxlen=max_len, sequences=y, padding="post", value=tag2idx["O"])

# %%
x_train, x_test, y_train, y_test=train_test_split(X, y, test_size=0.25, random_state=1)

# %%
input_word=Input(shape=(max_len,))
model=Embedding(input_dim=num_words, output_dim=50, input_length=max_len)(input_word)
model=SpatialDropout1D(0.1)(model)
model=Bidirectional(LSTM(units=100, return_sequences=True, recurrent_dropout=0.1))(model)
out=TimeDistributed(Dense(num_tags, activation="softmax"))(model)
model=Model(input_word, out)
model.summary()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 50)]              0
#
#  embedding (Embedding)       (None, 50, 50)            1150450
#
#  spatial_dropout1d (SpatialD  (None, 50, 50)           0
#  ropout1D)
#
#  bidirectional (Bidirectiona  (None, 50, 200)          120800
#  l)
#
#  time_distributed (TimeDistr  (None, 50, 17)           3417
#  ibuted)
#
# =================================================================
# Total params: 1,274,667
# Trainable params: 1,274,667
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
chkpt=ModelCheckpoint("model_weights.h5", monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=True, mode='min')
early_stopping=EarlyStopping(monitor='val_accuracy', min_delta=0, patience=1, verbose=0, mode='max', baseline=None, restore_best_weights=False)
history=model.fit(x=x_train, y=y_train, validation_data=(x_test,y_test), batch_size=32, epochs=5, verbose=1)
# Out:
# Epoch 1/5
# 465/465 [==============================] - 165s 343ms/step - loss: 0.3062 - accuracy: 0.9382 - val_loss: 0.1545 - val_accuracy: 0.9534
# Epoch 2/5
# 465/465 [==============================] - 155s 333ms/step - loss: 0.1132 - accuracy: 0.9673 - val_loss: 0.0883 - val_accuracy: 0.9761
# Epoch 3/5
# 465/465 [==============================] - 156s 335ms/step - loss: 0.0636 - accuracy: 0.9821 - val_loss: 0.0678 - val_accuracy: 0.9809
# Epoch 4/5
# 465/465 [==============================] - 156s 335ms/step - loss: 0.0460 - accuracy: 0.9867 - val_loss: 0.0625 - val_accuracy: 0.9821
# Epoch 5/5
# 465/465 [==============================] - 155s 332ms/step - loss: 0.0368 - accuracy: 0.9890 - val_loss: 0.0628 - val_accuracy: 0.9825

# %%
model.evaluate(x_test, y_test)
# Out:
# 155/155 [==============================] - 4s 28ms/step - loss: 0.0628 - accuracy: 0.9825
# [0.06279795616865158, 0.9825166463851929]

# %%
i=np.random.randint(0, x_test.shape[0]) 
p=model.predict(np.array([x_test[i]]))
p=np.argmax(p, axis=-1)
y_true = y_test[i]
print("{:15}{:5}\t {}\n".format("Word", "True", "Pred"))
print("-" *30)
for w, true, pred in zip(x_test[i], y_true, p[0]):
    print("{:15}{}\t{}".format(words[w-1], tags[true], tags[pred]))
# Out:
# 1/1 [==============================] - 0s 436ms/step
# Word           True 	 Pred
#
# ------------------------------
# President      B-per	B-per
# Bush           I-per	I-per
# said           O	O
# nations        O	O
# around         O	O
# the            O	O
# world          O	O
# need           O	O
# to             O	O
# stand          O	O
# with           O	O
# moderate       O	O
# reformers      O	O
# in             O	O
# the            O	O
# MIddle         B-geo	O
# East           I-geo	I-geo
# .              O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
# deteriorated   O	O
